# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
corona=pd.read_csv("G:\STUDY MCA\SEM_2\Python\corona.csv")
print(corona.columns)
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Age Bracket', 'Gender', 'Detected City', 'Detected District',
#        'Detected State', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
corona.head
# Out:
# <bound method NDFrame.head of       Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0                  1             KL-TS-P1     30/01/2020          20      F
# 1                  2             KL-AL-P1     02-02-2020         NaN    NaN
# 2                  3             KL-KS-P1     03-02-2020         NaN    NaN
# 3                  4                DL-P1     02-03-2020          45      M
# 4                  5                TS-P1     02-03-2020          24      M
# 5                  6                  NaN     03-03-2020          69      M
# 6                  7                  NaN     04-03-2020          55    NaN
# 7                  8                  NaN     04-03-2020          55    NaN
# 8                  9                  NaN     04-03-2020          55    NaN
# 9                 10                  NaN     04-03-2020          55    NaN
# 10                11                  NaN     04-03-2020          55    NaN
# 11                12                  NaN     04-03-2020          55    NaN
# 12                13                  NaN     04-03-2020          55    NaN
# 13                14                  NaN     04-03-2020          55    NaN
# 14                15                  NaN     04-03-2020          55    NaN
# 15                16                  NaN     04-03-2020          55    NaN
# 16                17                  NaN     04-03-2020          55    NaN
# 17                18                  NaN     04-03-2020          55    NaN
# 18                19                  NaN     04-03-2020          55    NaN
# 19                20                  NaN     04-03-2020          55    NaN
# 20                21                  NaN     04-03-2020          70      F
# 21                22                  NaN     04-03-2020         NaN    NaN
# 22                23                  NaN     04-03-2020         NaN    NaN
# 23                24                  NaN     04-03-2020         NaN    NaN
# 24                25                  NaN     04-03-2020         NaN    NaN
# 25                26                  NaN     04-03-2020         NaN    NaN
# 26                27                  NaN     04-03-2020         NaN    NaN
# 27                28                  NaN     04-03-2020         NaN    NaN
# 28                29                DL-P2     05-03-2020          27      M
# 29                30                  NaN     05-03-2020          59      M
# ...              ...                  ...            ...         ...    ...
# 1589            1590                  NaN     31/03/2020         NaN    NaN
# 1590            1591                  NaN     31/03/2020         NaN    NaN
# 1591            1592                  NaN     31/03/2020         NaN    NaN
# 1592            1593                  NaN     31/03/2020         NaN    NaN
# 1593            1594                  NaN     31/03/2020         NaN    NaN
# 1594            1595                  NaN     31/03/2020         NaN    NaN
# 1595            1596                  NaN     31/03/2020         NaN    NaN
# 1596            1597                  NaN     31/03/2020         NaN    NaN
# 1597            1598                  NaN     31/03/2020         NaN    NaN
# 1598            1599                  NaN     31/03/2020         NaN    NaN
# 1599            1600                  NaN     31/03/2020         NaN    NaN
# 1600            1601                  NaN     31/03/2020         NaN    NaN
# 1601            1602                  NaN     31/03/2020         NaN    NaN
# 1602            1603                  NaN     31/03/2020         NaN    NaN
# 1603            1604                  NaN     31/03/2020         NaN    NaN
# 1604            1605                  NaN     31/03/2020         NaN    NaN
# 1605            1606                  NaN     31/03/2020         NaN    NaN
# 1606            1607                  NaN     31/03/2020         NaN    NaN
# 1608                       NaN                  NaN    Chhattisgarh
# 1609                       NaN        Visakhapatnam  Andhra Pradesh
# 1610                       NaN        Visakhapatnam  Andhra Pradesh
# 1611                       NaN        Visakhapatnam  Andhra Pradesh
# 1612                       NaN        Visakhapatnam  Andhra Pradesh
# 1613                       NaN              Bhadrak          Odisha
# 1614                       NaN           Chandigarh      Chandigarh
# 1615                       NaN           Chandigarh      Chandigarh
# 1616                     NOIDA  Gautam Buddha Nagar   Uttar Pradesh
# 1617                     NOIDA  Gautam Buddha Nagar   Uttar Pradesh
# 1618                     NOIDA  Gautam Buddha Nagar   Uttar Pradesh
#
#      Current Status                                              Notes  \
# 0         Recovered                               Travelled from Wuhan
# 1         Recovered                               Travelled from Wuhan
# 2         Recovered                               Travelled from Wuhan
# 3         Recovered                      Travelled from Austria, Italy
# 4         Recovered  Travelled from Dubai to Bangalore on 20th Feb,...
# 5         Recovered                               Travelled from Italy
# 6         Recovered                               Travelled from Italy
# 7         Recovered                               Travelled from Italy
# 8         Recovered                               Travelled from Italy
# 9         Recovered                               Travelled from Italy
# 10        Recovered                               Travelled from Italy
# 11        Recovered                               Travelled from Italy
# 12        Recovered                               Travelled from Italy
# 13        Recovered                               Travelled from Italy
# 14        Recovered                               Travelled from Italy
# 15        Recovered                               Travelled from Italy
# 16        Recovered                               Travelled from Italy
# 17        Recovered                               Travelled from Italy
# 18     Hospitalized                               Travelled from Italy
# 19     Hospitalized                               Travelled from Italy
# 20        Recovered                   Travelled from Italy, Wife of P6
# 21     Hospitalized                               Family members of P4
# 22     Hospitalized                               Family members of P4
# 23     Hospitalized                               Family members of P4
# 24     Hospitalized                               Family members of P4
# 25     Hospitalized                               Family members of P4
# 26     Hospitalized                               Family members of P4
# 27     Hospitalized  Accompanied the Italian tourists, Nationality:...
# 28     Hospitalized                    Travelled from Italy PayTm Emp,
# 29        Recovered                                Travelled from Iran
# ...             ...                                                ...
# 1589   Hospitalized                                    Details Awaited
# 1590   Hospitalized                                    Details Awaited
# 1591   Hospitalized                                    Details Awaited
# 1592   Hospitalized                                    Details Awaited
# 1593   Hospitalized                                    Details Awaited
# 1594   Hospitalized                                    Details Awaited
# 1595   Hospitalized                                    Details Awaited
# 1596   Hospitalized                                    Details Awaited
# 1597   Hospitalized                                    Details Awaited
# 1598   Hospitalized                                    Details Awaited
# 1599   Hospitalized                                    Details Awaited
# 1600   Hospitalized                                    Details Awaited
# 1601   Hospitalized                                    Details Awaited
# 1602   Hospitalized                                    Details Awaited
# 1603   Hospitalized                                    Details Awaited
# 1604   Hospitalized                                    Details Awaited
# 1605   Hospitalized                                    Details Awaited
# 1606   Hospitalized                                    Details Awaited
# 1607   Hospitalized                                    Details Awaited
# 1608   Hospitalized                                  Travelled from UK
# 1609   Hospitalized                Attended Delhi Religious Conference
# 1610   Hospitalized                Attended Delhi Religious Conference
# 1612     ...       https://twitter.com/ANI/status/124504363340703...
# 1613     ...                                                     NaN
# 1614     ...       https://www.tribuneindia.com/news/chandigarh/t...
# 1615     ...       https://www.tribuneindia.com/news/chandigarh/t...
# 1616     ...       https://twitter.com/TOINoida/status/1245042581...
# 1617     ...       https://twitter.com/TOINoida/status/1245042581...
# 1618     ...       https://twitter.com/TOINoida/status/1245042581...
#
#                                                Source_3  \
# 0                                                   NaN
# 1                                                   NaN
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3                                                   NaN
# 4     https://www.thehindu.com/news/national/coronav...
# 5     https://twitter.com/PTI_News/status/1240878975...
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    https://economictimes.indiatimes.com/news/poli...
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29    https://timesofindia.indiatimes.com/city/mumba...
# ...                                                 ...
# 1589                                                NaN
# 1590                                                NaN
# 1591                                                NaN
# 1592                                                NaN
# 1593                                                NaN
# 1594                                                NaN
# 1595                                                NaN
# 1596                                                NaN
# 1597                                                NaN
# 1598                                                NaN
# 1599                                                NaN
# 1600                                                NaN
# 1601                                                NaN
# 1602                                                NaN
# 1603                                                NaN
# 1604                                                NaN
# 1605                                                NaN
# 1606                                                NaN
# 1607                                                NaN
# 1608                                                NaN
# 1609                                                NaN
# 1610                                                NaN
# 1611                                                NaN
# 1612                                                NaN
# 1613                                                NaN
# 1614                                                NaN
# 1615                                                NaN
# 1616                                                NaN
# 1617                                                NaN
# 1618                                                NaN
#
#                                      Backup Notes Unnamed: 18 Unnamed: 19  \
# 0                              Student from Wuhan         NaN         NaN
# 1                              Student from Wuhan         NaN         NaN
# 2                              Student from Wuhan         NaN         NaN
# 3             Travel history to Italy and Austria         NaN         NaN
# 4      Travel history to Dubai, Singapore contact         NaN         NaN
# 5                                 Italian tourist         NaN         NaN
# 6                                 Italian tourist         NaN         NaN
# 7                                 Italian tourist         NaN         NaN
# 8                                 Italian tourist         NaN         NaN
# 9                                 Italian tourist         NaN         NaN
# 10                                Italian tourist         NaN         NaN
# 11                                Italian tourist         NaN         NaN
# 12                                Italian tourist         NaN         NaN
# 13                                Italian tourist         NaN         NaN
# 14                                Italian tourist         NaN         NaN
# 15                                Italian tourist         NaN         NaN
# 16                                Italian tourist         NaN         NaN
# 17                                Italian tourist         NaN         NaN
# 18                                Italian tourist         NaN         NaN
# 19                                Italian tourist         NaN         NaN
# 20                   Italian tourist (wife of P6)         NaN         NaN
# 21                           Family members of P4         NaN         NaN
# 22                           Family members of P4         NaN         NaN
# 23                           Family members of P4         NaN         NaN
# 24                           Family members of P4         NaN         NaN
# 25                           Family members of P4         NaN         NaN
# 26                           Family members of P4         NaN         NaN
# 27    Indian who accompanied the Italian tourists         NaN         NaN
# 28                PayTm Emp, Travelled from Italy         NaN         NaN
# 29                              Travelled to Iran         NaN         NaN
# ...                                           ...         ...         ...
# 1589                                          NaN         NaN         NaN
# 1590                                          NaN         NaN         NaN
# 1595         NaN         NaN         NaN          NaN          NaN
# 1596         NaN         NaN         NaN          NaN          NaN
# 1597         NaN         NaN         NaN          NaN          NaN
# 1598         NaN         NaN         NaN          NaN          NaN
# 1599         NaN         NaN         NaN          NaN          NaN
# 1600         NaN         NaN         NaN          NaN          NaN
# 1601         NaN         NaN         NaN          NaN          NaN
# 1602         NaN         NaN         NaN          NaN          NaN
# 1603         NaN         NaN         NaN          NaN          NaN
# 1604         NaN         NaN         NaN          NaN          NaN
# 1605         NaN         NaN         NaN          NaN          NaN
# 1606         NaN         NaN         NaN          NaN          NaN
# 1607         NaN         NaN         NaN          NaN          NaN
# 1608         NaN         NaN         NaN          NaN          NaN
# 1609         NaN         NaN         NaN          NaN          NaN
# 1610         NaN         NaN         NaN          NaN          NaN
# 1611         NaN         NaN         NaN          NaN          NaN
# 1612         NaN         NaN         NaN          NaN          NaN
# 1613         NaN         NaN         NaN          NaN          NaN
# 1614         NaN         NaN         NaN          NaN          NaN
# 1615         NaN         NaN         NaN          NaN          NaN
# 1616         NaN         NaN         NaN          NaN          NaN
# 1617         NaN         NaN         NaN          NaN          NaN
# 1618         NaN         NaN         NaN          NaN          NaN
#
# [1619 rows x 25 columns]>

# %%
plt.plot(state=corona["Detected State"].value_counts())
plt.show()

# %%
state=corona["Detected State"].value_counts()
state.plot.barh(figsize=(15,15),title="NUMBER OF CASES BY STATE")
plt.savefig("2_Cases By State.png",dpi=960)
plt.show()

# %%
gender_by_state=corona.groupby(["Detected State","Gender"])["Gender"].count()
gender_by_state.unstack().plot.barh(figsize=[15,15],stacked=True,color=["#FF00FF","#104E8B"])
plt.savefig("3_cases by gender,state.png",dpi=960)
plt.show()

# %%
corona["Age Bracket"] = corona["Age Bracket"].fillna("NIA")
crna=corona["Age Bracket"].value_counts()
print(crna)
# Out:
# NIA      1001
# 21         25
# 35         22
# 32         21
# 24         20
# 55         20
# 23         19
# 45         19
# 65         18
# 25         18
# 22         17
# 27         15
# 40         15
# 26         15
# 33         13
# 34         13
# 38         13
# 52         13
# 41         12
# 20         12
# 53         11
# 39         11
# 60         10
# 37         10
# 30         10
# 50         10
# 63         10
# 49         10
# 42          9
# 59          9
#          ...
# 19          5
# 61          5
# 3           5
# 28-35       4
# 68          4
# 1           4
# 17          3
# 75          3
# 62          3
# 66          3
# 76          3
# 74          3
# 7           2
# 13          2
# 85          2
# 2           2
# 81          2
# 11          2
# 14          1
# 96          1
# 89          1
# 10          1
# 9           1
# 77          1
# 73          1
# 12          1
# 15          1
# 6           1
# 72          1
# 92          1
# Name: Age Bracket, Length: 79, dtype: int64

# %%
plt.hist(crna,color="#ffbd33")
plt.show()

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/raw_data.json" 
data = requests.get(url=URL).json()
sex=pd.DataFrame(data["raw_data"])
female=sex[sex["gender"]=="F"]
male=sex[sex["gender"]=="M"]
no_total=sex['patientnumber'].count()
no_female=female['patientnumber'].count()
no_male=male['patientnumber'].count()
nan=no_total-no_female-no_male
y=[no_male,no_female,nan]
x=['Male','Female','NaN']
plt.bar(x,y,color=["yellow","pink","orange"])
plt.show()

# %%
#taking diff no of bins in "dectected city"
plt.hist('Detected City',bins=5)
plt.show()
plt.clf()
plt.hist('Detected City',bins=10)
plt.show()

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/data.json" 
data = requests.get(url=URL).json()
covid19_df = json_normalize(data['statewise'])
def barplt(st1,st2):
    c1=int(covid19_df[covid19_df.state==st1]['confirmed'])
    a1=int(covid19_df[covid19_df.state==st1]['active'])
    d1=int(covid19_df[covid19_df.state==st1]['deaths'])
    r1=int(covid19_df[covid19_df.state==st1]['recovered'])
    c2=int(covid19_df[covid19_df.state==st2]['confirmed'])
    a2=int(covid19_df[covid19_df.state==st2]['active'])
    d2=int(covid19_df[covid19_df.state==st2]['deaths'])
    r2=int(covid19_df[covid19_df.state==st2]['recovered'])
    x1=[c1,a1,d1,r1]
    x2=[c2,a2,d2,r2]
    y=['confirmed','active','deaths','recovered']
    xpos=np.arange(len(y))
    plt.bar(xpos-0.2,x1,width=0.4,label=st1)
    plt.bar(xpos+0.2,x2,width=0.4,label=st2)
    plt.xlabel("Category")
    plt.ylabel("No. of cases")
    plt.title(st1+" and "+st2)
    plt.xticks(xpos,y)
    plt.legend()
    plt.show()
stn1=input("Enter The name of State : ")
stn2=input("Enter The name of State : ")
barplt(stn1.capitalize(),stn2.capitalize()) #call the function to draw the barplot between two states
# Out:
# Enter The name of State : Kerala
# Enter The name of State : Maharashtra

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
URL = "https://api.covid19india.org/data.json" 
data = requests.get(url=URL).json()
covid19_df = json_normalize(data['statewise'])
def barplt(st1,st2):
    c1=int(covid19_df[covid19_df.state==st1]['confirmed'])
    a1=int(covid19_df[covid19_df.state==st1]['active'])
    d1=int(covid19_df[covid19_df.state==st1]['deaths'])
    r1=int(covid19_df[covid19_df.state==st1]['recovered'])
    c2=int(covid19_df[covid19_df.state==st2]['confirmed'])
    a2=int(covid19_df[covid19_df.state==st2]['active'])
    d2=int(covid19_df[covid19_df.state==st2]['deaths'])
    r2=int(covid19_df[covid19_df.state==st2]['recovered'])
    x1=[c1,a1,d1,r1]
    x2=[c2,a2,d2,r2]
    y=['confirmed','active','deaths','recovered']
    xpos=np.arange(len(y))
    plt.bar(xpos-0.2,x1,width=0.4,label=st1)
    plt.bar(xpos+0.2,x2,width=0.4,label=st2)
    plt.xlabel("Category")
    plt.ylabel("No. of cases")
    plt.title(st1+" and "+st2)
    plt.xticks(xpos,y)
    plt.legend()
    plt.show()
stn1=input("Enter The name of State : ")
stn2=input("Enter The name of State : ")
barplt(stn1.capitalize(),stn2.capitalize()) #call the function to draw the barplot between two states
# Out:
# Enter The name of State : Gujarat
# Enter The name of State : Delhi
